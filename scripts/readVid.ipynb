# %%
import cv2
import numpy as np
import os
import pandas as pd

# %%
video_info = pd.read_csv('../EchoNet-Dynamic/EchoNet-Dynamic/VolumeTracings.csv')
video_info
# Out:
#                       FileName         X1         Y1         X2         Y2  \
# 0       0X100009310A3BD7FC.avi  51.260417  15.348958  64.932292  69.125000
# 1       0X100009310A3BD7FC.avi  50.037611  17.167841  53.367222  16.321330
# 2       0X100009310A3BD7FC.avi  49.157378  20.407629  57.090549  18.390722
# 3       0X100009310A3BD7FC.avi  48.538173  23.581055  59.997339  20.667707
# 4       0X100009310A3BD7FC.avi  47.918968  26.754480  62.904129  22.944693
# ...                        ...        ...        ...        ...        ...
# 425005   0XFEBEEFF93F6FEB9.avi  45.419984  55.131136  69.758942  57.498739
# 425006   0XFEBEEFF93F6FEB9.avi  45.017994  57.543075  69.399107  59.914779
# 425007   0XFEBEEFF93F6FEB9.avi  44.616005  59.955014  69.039271  62.330818
# 425008   0XFEBEEFF93F6FEB9.avi  44.214015  62.366952  68.712853  64.750108
# 425009   0XFEBEEFF93F6FEB9.avi  59.371804  66.292488  68.501507  67.180591
#
#         Frame
# 0          46
# 1          46
# 2          46
# ...

# %%
path = '../EchoNet-Dynamic/EchoNet-Dynamic/Videos/'
files = os.listdir(path)

# %%
for file in files[: 5]:
    path_file = os.path.join(path, file)
    cap = cv2.VideoCapture(path_file)
    frames = video_info[video_info.FileName == file]['Frame'].unique()
    for frame in frames:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame)
        coor = video_info[(video_info.FileName == file) & (video_info.Frame == frame)]
        puntos1 = [(int(row['X1']), int(row['Y1'])) for index, row in coor.iterrows()]
        puntos2 = [(int(row['X2']), int(row['Y2'])) for index, row in coor.iterrows()]
        ret, img = cap.read()
        if ret:
            for punto in puntos1:
                cv2.circle(img, punto, 1, (0, 255, 0), -1)
            
            for punto in puntos2:
                cv2.circle(img, punto, 1, (0, 255, 0), -1)

            img_rsz = cv2.resize(img, (500, 500))
            cv2.imshow('Image', img_rsz)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

# %%
for file in files[: 3]:
    path_file = os.path.join(path, file)
    cap = cv2.VideoCapture(path_file)
    frames = video_info[video_info.FileName == file]['Frame'].unique()
    for frame in frames:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame)
        coor = video_info[(video_info.FileName == file) & (video_info.Frame == frame)]
        puntos1 = [(int(row['X1']), int(row['Y1'])) for index, row in coor.iterrows()]
        puntos2 = [(int(row['X2']), int(row['Y2'])) for index, row in coor.iterrows()]
        poly = np.array(np.concatenate((puntos1, puntos2), axis=0).tolist(), np.int32)
        ret, img = cap.read()
        img1 = np.zeros(img.shape[:2],  dtype=np.uint8)
        cv2.fillPoly(img1, [poly], 255)
        img_rsz = cv2.resize(img1, (300, 300))
        cv2.imshow('Image', img_rsz)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
for file in files[:10]:
    path_file = os.path.join(path, file)
    cap = cv2.VideoCapture(path_file)
    frames = video_info[video_info.FileName == file]['Frame'].unique()
    for frame in frames:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame)
        coor = video_info[(video_info.FileName == file) & (video_info.Frame == frame)]
        puntos1 = [(int(row['X1']), int(row['Y1'])) for index, row in coor.iterrows()]
        puntos2 = [(int(row['X2']), int(row['Y2'])) for index, row in coor.iterrows()]
        puntos2.pop(0)
        puntos2.reverse()
        puntos2.append(puntos1[0])
        poly = np.array(np.concatenate((puntos1, puntos2), axis=0).tolist(), np.int32)
        ret, img = cap.read()
        if ret:
            img1 = np.zeros(img.shape[:2],  dtype=np.uint8)
            cv2.fillPoly(img1, [poly], 255)
            for punto in poly:
                cv2.circle(img, punto, 1, (0, 255, 0), -1)

            name = os.path.join('../EchoNet-Dynamic/EchoNet-Dynamic/masked/', file[0:-4] + '_' + str(frame) + '.jpg')
            cv2.imwrite(name, img1)
            print(name)
            #img_rsz = cv2.resize(img, (500, 500))
            #img1 = cv2.resize(img1, (500, 500))
            #cv2.imshow('Image resized', img_rsz)
            #cv2.imshow('Masked', img1)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
# Out:
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100009310A3BD7FC_46.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100009310A3BD7FC_61.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X1002E8FBACD08477_3.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X1002E8FBACD08477_18.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X1005D03EED19C65B_24.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X1005D03EED19C65B_35.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X10075961BC11C88E_91.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X10075961BC11C88E_108.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X10094BA0A028EAC3_137.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X10094BA0A028EAC3_156.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100CF05D141FF143_132.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100CF05D141FF143_148.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100E3B8D3280BEC5_25.jpg
# ../EchoNet-Dynamic/EchoNet-Dynamic/masked/0X100E3B8D3280BEC5_38.jpg
# ...
